# %% [markdown]
# # Scikit learn - sklearn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Process of filling missing data - Imputation
# * Pricess of turning non numerical values to numerical values - Feature engineering or Feature scaling

# %% [markdown]
# 1. Getting the Data ready:
#     * Fill missing data - Imputation
#     * Turn non numerical values (strings etc) to Numerical values - Feature engineering.
#
# 2. Selecting the righ ML model:
#     *
